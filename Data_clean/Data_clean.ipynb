# %%
 from dev_tools import say_hello, autoclean_dataset
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from dev_tools import say_hello, autoclean_dataset
#
# ModuleNotFoundError: No module named 'dev_tools'

# %%
autoclean_dataset('D:\\Sky_Analytics\\Datasets\\df_logs_vols\\logs_vols.csv')
# Out:
# Résumé des données :
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 99     │ │ string      │ 4     │                                                          │
# │ │ Number of columns │ 6      │ │ float64     │ 1     │                                                          │
# │ └───────────────────┴────────┘ │ int32       │ 1     │                                                          │
# ...

# %% [markdown]
# # Essais ML

# %%
import pandas as pd
import numpy as np

# %%
df_aeronefs = pd.read_csv('/Users/um/Desktop/Wild Code School/1_Top_gun/Datasets/df_aeronef/df_aeronef_clean.csv')
df_composants = pd.read_csv('/Users/um/Desktop/Wild Code School/1_Top_gun/Datasets/df_composants/df_composants_clean.csv')
df_degradation = pd.read_csv('/Users/um/Desktop/Wild Code School/1_Top_gun/Data_clean/degradations_full_cleaned.csv')
df_logsvols = pd.read_csv('/Users/um/Desktop/Wild Code School/1_Top_gun/Data_clean/logs_vols_full_cleaned.csv')

# %%
df_aeronefs.head(1)
# Out:
#     ref_aero type_model debut_service  last_maint  en_maintenance   end_maint
# 0  E170_6353       E170    2000-03-17  2024-03-27               0  1970-01-01

# %%
df_aeronefs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232 entries, 0 to 231
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ref_aero        232 non-null    object
#  1   type_model      232 non-null    object
#  2   debut_service   232 non-null    object
#  3   last_maint      232 non-null    object
#  4   en_maintenance  232 non-null    int64
#  5   end_maint       232 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 11.0+ KB
