# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/um/Desktop/Wild Code School/Projet_Top_Gun/logs_vols_2024-06-02.csv')

# %%
df
# Out:
#       ref_vol aero_linked    jour_vol  time_en_air  \
# 0   V07679725   B767_4924  2024-06-02          7.0
# 1   V02564879   B747_3165  2024-06-02          5.1
# 2   V07933973   B757_2518  2024-06-02          7.7
# 3   V02230187   A340_1047  2024-06-02          6.1
# 4   V09071213   B757_6806  2024-06-02          4.5
# ..        ...         ...         ...          ...
# 94  V06477218   B757_4595  2024-06-02          4.7
# 95  V03133569   B737_1256  2024-06-02          6.4
# 96  V01537338   E170_2943  2024-06-02          6.4
# 97  V01318087   A350_6495  2024-06-02          5.9
# 98  V04468315   B777_3776  2024-06-02          1.3
#
#                                           sensor_data  etat_voyant
# 0   {'temp': '-5.7°C', 'pressure': '930.6 hPa', 'v...            0
# 1   {'temp': '0.9°C', 'pressure': '950.6 hPa', 'vi...            0
# 2   {'temp': '-6.2°C', 'pressure': '975.5 hPa', 'v...            3
# 3   {'temp': '-25.3°C', 'pressure': '945.1 hPa', '...            1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ref_vol      99 non-null     object
#  1   aero_linked  99 non-null     object
#  2   jour_vol     99 non-null     object
#  3   time_en_air  99 non-null     float64
#  4   sensor_data  99 non-null     object
#  5   etat_voyant  99 non-null     int64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 4.8+ KB

# %%
df.sensor_data.unique()
# Out:
# array(["{'temp': '-5.7°C', 'pressure': '930.6 hPa', 'vibrations': '3.1163905014858932 m/s²'}",
#        "{'temp': '0.9°C', 'pressure': '950.6 hPa', 'vibrations': '4.5578253809563725 m/s²'}",
#        "{'temp': '-6.2°C', 'pressure': '975.5 hPa', 'vibrations': '4.58707061982232 m/s²'}",
#        "{'temp': '-25.3°C', 'pressure': '945.1 hPa', 'vibrations': '3.287868564197513 m/s²'}",
#        "{'temp': '11.1°C', 'pressure': '931.3 hPa', 'vibrations': '2.8166257793381355 m/s²'}",
#        "{'temp': '6.7°C', 'pressure': '929.1 hPa', 'vibrations': '4.395360606179412 m/s²'}",
#        "{'temp': '-3.3°C', 'pressure': '901.4 hPa', 'vibrations': '0.11158576392007458 m/s²'}",
#        "{'temp': '9.7°C', 'pressure': '861.6 hPa', 'vibrations': '4.045373429186297 m/s²'}",
#        "{'temp': '-1.8°C', 'pressure': '938.3 hPa', 'vibrations': '3.246045907069765 m/s²'}",
#        "{'temp': '1.3°C', 'pressure': '987.4 hPa', 'vibrations': '0.0731033741033088 m/s²'}",
# ...
