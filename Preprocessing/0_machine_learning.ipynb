# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import create_engine
import sqlite3

# %%
conn = sqlite3.connect('/Users/um/Desktop/Wild Code School/Top_gun/Datasets/top_gun_data_1.db')

# %%
df_aeronefs = pd.read_sql_query('select * from aeronefs', conn)
df_composants = pd.read_sql_query('select * from composants', conn)
df_degradations = pd.read_sql_query('select * from degradations', conn)
df_logs_vols = pd.read_sql_query('select * from logs_vols', conn)

# %%
df_degradations['measure_day'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # Téléchargement des datasets via la base sql.

# %%
display(df_aeronefs.head(1))
display(df_composants.head(1))
display(df_degradations.head(1))
display(df_logs_vols.head(1))
# Out:
#     ref_aero type_model debut_service  last_maint  en_maintenance   end_maint
# 0  E170_6353       E170    2000-03-17  2024-03-27               0  1970-01-01
#              ref_compo  categorie       aero             desc  lifespan  \
# 0  REAE170-E170_6353-0          2  E170_6353  Réacteur gauche   13045.0
#
#    taux_usure_actuel     cout
# 0          53.308375  15552.0
#    ref_deg linked_aero      compo_concerned  usure_nouvelle measure_day  \
# 0  D003661   E170_6353  REAE170-E170_6353-0            53.0  2024-06-01
#
#    need_replacement
# 0                 0
#      ref_vol aero_linked    jour_vol  time_en_air  etat_voyant  temp en °C  \
# 0  V07679725   B767_4924  2024-06-02          7.0            0        -5.7
#
#    pressure en hPa  vibrations en m/s²
# 0            930.6               3.116

# %%
df_aeronefs
# Out:
#          id_aero type_model debut_service  last_maint  en_maintenance  \
# 0      E170_6353       E170    2000-03-17  2024-03-27               0
# 1      B767_2803       B767    2020-12-03  2024-06-01               0
# 2    CRJ700_6943     CRJ700    2015-01-29  2024-06-02               1
# 3      A350_1177       A350    2005-08-07  2024-01-04               0
# 4      B777_4029       B777    2009-01-01  2024-06-01               0
# ..           ...        ...           ...         ...             ...
# 225    A350_6305       A350    2009-03-09  2024-06-01               0
# 226    B737_4369       B737    2010-01-05  2024-06-01               0
# 227    A340_4021       A340    2004-12-13  2024-05-31               0
# 228  CRJ900_1740     CRJ900    2003-07-20  2024-06-01               0
# 229  CRJ700_2988     CRJ700    2000-10-25  2024-02-01               0
#
#       end_maint
# 0    1970-01-01
# 1    1970-01-01
# 2    2024-06-03
# 3    1970-01-01
# 4    1970-01-01
# ..          ...
# 225  1970-01-01
# 226  1970-01-01
# 227  1970-01-01
# 228  1970-01-01
# 229  1970-01-01
#
# [230 rows x 6 columns]

# %%
df_composants
# Out:
#                       ref_compo  categorie      id_aero  \
# 0           REAE170-E170_6353-0          2    E170_6353
# 1           REAE170-E170_6353-1          2    E170_6353
# 2           SYSE170-E170_6353-2          2    E170_6353
# 3           ORDE170-E170_6353-3          2    E170_6353
# 4           AUTE170-E170_6353-4          2    E170_6353
# ...                         ...        ...          ...
# 10345  SYSCRJ700-CRJ700_2988-40          0  CRJ700_2988
# 10346  PORCRJ700-CRJ700_2988-41          0  CRJ700_2988
# 10347  HUBCRJ700-CRJ700_2988-42          0  CRJ700_2988
# 10348  ECLCRJ700-CRJ700_2988-43          0  CRJ700_2988
# 10349  SYSCRJ700-CRJ700_2988-44          0  CRJ700_2988
#
#                                      desc  lifespan  taux_usure_actuel  \
# 0                         Réacteur gauche   13045.0          53.308375
# 1                          Réacteur droit   13626.0          50.111950
# 2                   Système de navigation   10541.0          16.730575
# 3                       Ordinateur de vol   10441.0           6.653075
# 4                              Autopilote   14847.0          42.033525
# ...                                   ...       ...                ...
# 10345        Systèmes d'oxygène d'urgence   13038.0          53.323168
# 10346                    Portes passagers   13107.0          16.392552
# 10347                             Hublots   68978.0          34.551008
# 10348              Éclairage de la cabine   10639.0          36.706904
# 10349  Système d'approvisionnement en eau   12796.0          13.740256
#
#           cout
# 0      15552.0
# 1      17559.0
# 2      16514.0
# 3      16047.0
# 4      19362.0
# ...        ...
# 10345   4745.0
# 10346   3053.0
# 10347   3593.0
# 10348   4965.0
# 10349   4701.0
#
# [10350 rows x 7 columns]

# %%
df_aeronefs['en_maintenance'].sort_index().value_counts()
# Out:
# en_maintenance
# 0    215
# 1     15
# Name: count, dtype: int64

# %%
df_degradations.isnull().sum()
# Out:
# ref_deg             0
# linked_aero         0
# compo_concerned     0
# usure_nouvelle      0
# measure_day         0
# need_replacement    0
# dtype: int64

# %% [markdown]
# # Renommage des colonnes pour faciliter la jointure.

# %%
df_aeronefs.rename(columns={"ref_aero": "id_aero"}, inplace=True)
df_composants.rename(columns={"aero": "id_aero"}, inplace=True)
df_degradations.rename(columns={"linked_aero": "id_aero","compo_concerned" : "ref_compo"}, inplace=True)
df_logs_vols.rename(columns={"aero_linked": "id_aero"}, inplace=True)

# %%
data = pd.merge(df_degradations, df_logs_vols, on='id_aero', how='left')

# %%
data = pd.merge(data, df_composants, on='ref_compo', how = 'left')

# %%
data.duplicated().sum()
# Out:
# 0

# %%
"""
je choisi de droper les colonnes qui ne me seront pas utiles à ce niveau : ref_deg, id_aero_y, measure_day, ref_vol.
je renomme la colonne usure_nouvelle par usure_cumulée, afin d'avoir une meilleure compréhension du dataset.
le fichier data = df_degradations + df_logs_vols + df_composants.
le fichier qui en résulte fait 479205 lignes.
"""
# Out:
# "\nje choisi de droper les colonnes qui ne me seront pas utiles à ce niveau : ref_deg, id_aero_y, measure_day, ref_vol.\nje renomme la colonne usure_nouvelle par usure_cumulée, afin d'avoir une meilleure compréhension du dataset.\nle fichier data = df_degradations + df_logs_vols + df_composants.\nle fichier qui en résulte fait 479205 lignes.\n"

# %%
data.drop(columns = ['ref_deg', 'id_aero_y', 'ref_vol'], inplace = True)

# %%
data.rename(columns={"usure_nouvelle": "usure_cumulée",
                     "id_aero_x": "id_aero",
                     }, inplace=True)

# %%
pd.set_option('display.max_columns', None)
data.head(10)
# Out:
#      id_aero            ref_compo  usure_cumulée measure_day  \
# 0  E170_6353  REAE170-E170_6353-0           53.0  2024-06-01
# 1  E170_6353  REAE170-E170_6353-0           53.0  2024-06-01
# 2  E170_6353  REAE170-E170_6353-0           53.0  2024-06-01
# 3  E170_6353  REAE170-E170_6353-0           53.0  2024-06-01
# 4  E170_6353  REAE170-E170_6353-0           53.0  2024-06-01
# 5  E170_6353  REAE170-E170_6353-0           53.0  2024-06-01
# 6  E170_6353  REAE170-E170_6353-1           50.0  2024-06-01
# 7  E170_6353  REAE170-E170_6353-1           50.0  2024-06-01
# 8  E170_6353  REAE170-E170_6353-1           50.0  2024-06-01
# 9  E170_6353  REAE170-E170_6353-1           50.0  2024-06-01
#
#    need_replacement   jour_vol  time_en_air  etat_voyant  temp en °C  \
# 0                 0 2024-06-04          6.9            0        -2.2
# 1                 0 2024-06-06          1.8            0         2.9
# 2                 0 2024-06-07          9.9            1       -12.4
# 3                 0 2024-06-11          6.7            0         1.7
# 4                 0 2024-06-12          6.9            0         3.7
# 5                 0 2024-06-16          9.0            1       -34.6
# 6                 0 2024-06-04          6.9            0        -2.2
# 7                 0 2024-06-06          1.8            0         2.9
# 8                 0 2024-06-07          9.9            1       -12.4
# 9                 0 2024-06-11          6.7            0         1.7
#
#    pressure en hPa  vibrations en m/s²  categorie             desc  lifespan  \
# 0            980.7               1.235          2  Réacteur gauche   13045.0
# 1            953.5               0.942          2  Réacteur gauche   13045.0
# 2            918.2               3.568          2  Réacteur gauche   13045.0
# 3            944.9               3.377          2  Réacteur gauche   13045.0
# 4            984.5               4.178          2  Réacteur gauche   13045.0
# 5            836.7               1.176          2  Réacteur gauche   13045.0
# 6            980.7               1.235          2   Réacteur droit   13626.0
# 7            953.5               0.942          2   Réacteur droit   13626.0
# 8            918.2               3.568          2   Réacteur droit   13626.0
# 9            944.9               3.377          2   Réacteur droit   13626.0
#
#    taux_usure_actuel     cout
# 0          53.308375  15552.0
# 1          53.308375  15552.0
# 2          53.308375  15552.0
# 3          53.308375  15552.0
# 4          53.308375  15552.0
# 5          53.308375  15552.0
# 6          50.111950  17559.0
# 7          50.111950  17559.0
# 8          50.111950  17559.0
# 9          50.111950  17559.0

# %%
data['etat_voyant'].value_counts()
# Out:
# etat_voyant
# 0    419760
# 1     58410
# 3       585
# 2       450
# Name: count, dtype: int64

# %%
date_columns = ['measure_day', 'jour_vol']
data[date_columns] = data[date_columns].apply(pd.to_datetime)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479205 entries, 0 to 479204
# Data columns (total 16 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id_aero             479205 non-null  object
#  1   ref_compo           479205 non-null  object
#  2   usure_cumulée       479205 non-null  float64
#  3   measure_day         479205 non-null  datetime64[ns]
#  4   need_replacement    479205 non-null  int64
#  5   jour_vol            479205 non-null  datetime64[ns]
#  6   time_en_air         479205 non-null  float64
#  7   etat_voyant         479205 non-null  int64
#  8   temp en °C          479205 non-null  float64
#  9   pressure en hPa     479205 non-null  float64
#  10  vibrations en m/s²  479205 non-null  float64
#  11  categorie           479205 non-null  int64
#  12  desc                479205 non-null  object
#  13  lifespan            479205 non-null  float64
#  14  taux_usure_actuel   479205 non-null  float64
#  15  cout                479205 non-null  float64
# dtypes: datetime64[ns](2), float64(8), int64(3), object(3)
# memory usage: 58.5+ MB

# %%
plt.figure(figsize=(15,10))
mumeric_columns = data.select_dtypes(include=['float64', 'int64']).columns
matrix = data[mumeric_columns].corr()
mask = np.triu(np.ones_like(matrix, dtype=bool))
sns.heatmap(matrix, annot=True, cmap='coolwarm', mask = mask)
plt.title('Correlation matrix')
plt.show()

# %%
data['ref_compo'].nunique()
# Out:
# 10350

# %%
data[data['id_aero'] == 'E170_6353'].sort_values(by='jour_vol', ascending=False).head(44)
# Out:
#           id_aero             ref_compo  usure_cumulée measure_day  \
# 438614  E170_6353  SYSE170-E170_6353-44           27.0  2024-06-16
# 308132  E170_6353   SYSE170-E170_6353-2           19.0  2024-06-11
# 308144  E170_6353   AUTE170-E170_6353-4           46.0  2024-06-11
# 329876  E170_6353  GOUE170-E170_6353-26           35.0  2024-06-12
# 167492  E170_6353   SYSE170-E170_6353-7           27.0  2024-06-06
# 89291   E170_6353   REAE170-E170_6353-1           51.0  2024-06-04
# 329882  E170_6353  SYSE170-E170_6353-27            9.0  2024-06-12
# 308138  E170_6353   ORDE170-E170_6353-3            9.0  2024-06-11
# 329888  E170_6353  SYSE170-E170_6353-28            5.0  2024-06-12
# 89285   E170_6353   REAE170-E170_6353-0           54.0  2024-06-04
# 167498  E170_6353   SYSE170-E170_6353-8            4.0  2024-06-06
# 329894  E170_6353  SYSE170-E170_6353-29           53.0  2024-06-12
# 186479  E170_6353  SYSE170-E170_6353-44           24.0  2024-06-07
# 269     E170_6353  SYSE170-E170_6353-44           22.0  2024-06-01
# 167504  E170_6353   SYSE170-E170_6353-9           32.0  2024-06-06
# 329900  E170_6353  ECLE170-E170_6353-30           52.0  2024-06-12
# 308126  E170_6353   REAE170-E170_6353-1           54.0  2024-06-11
# 263     E170_6353  ECLE170-E170_6353-43           51.0  2024-06-01
# 308120  E170_6353   REAE170-E170_6353-0           57.0  2024-06-11
# 329906  E170_6353  SIEE170-E170_6353-31           24.0  2024-06-12
# 167510  E170_6353  SYSE170-E170_6353-10           28.0  2024-06-06
# 329912  E170_6353  SIEE170-E170_6353-32           45.0  2024-06-12
# 89297   E170_6353   SYSE170-E170_6353-2           17.0  2024-06-04
# 308150  E170_6353   SYSE170-E170_6353-5            9.0  2024-06-11
# 329870  E170_6353  SYSE170-E170_6353-25           14.0  2024-06-12
# 167486  E170_6353   RADE170-E170_6353-6           23.0  2024-06-06
# 308180  E170_6353  SYSE170-E170_6353-10           30.0  2024-06-11
# 89327   E170_6353   SYSE170-E170_6353-7           27.0  2024-06-04
# 329834  E170_6353  SYSE170-E170_6353-19           37.0  2024-06-12
# 167468  E170_6353   ORDE170-E170_6353-3            8.0  2024-06-06
# 329840  E170_6353  AILE170-E170_6353-20           54.0  2024-06-12
# 89321   E170_6353   RADE170-E170_6353-6           23.0  2024-06-04
# 308174  E170_6353   SYSE170-E170_6353-9           34.0  2024-06-11
# 308168  E170_6353   SYSE170-E170_6353-8            6.0  2024-06-11
# 329846  E170_6353  EMPE170-E170_6353-21           55.0  2024-06-12
# 89315   E170_6353   SYSE170-E170_6353-5            6.0  2024-06-04
# 167474  E170_6353   AUTE170-E170_6353-4           43.0  2024-06-06
# 329852  E170_6353  FLAE170-E170_6353-22            9.0  2024-06-12
# 308162  E170_6353   SYSE170-E170_6353-7           29.0  2024-06-11
# 89309   E170_6353   AUTE170-E170_6353-4           43.0  2024-06-04
# 329858  E170_6353  SPOE170-E170_6353-23            9.0  2024-06-12
# 167480  E170_6353   SYSE170-E170_6353-5            7.0  2024-06-06
# 308156  E170_6353   RADE170-E170_6353-6           25.0  2024-06-11
# 329864  E170_6353  FREE170-E170_6353-24           33.0  2024-06-12
#
#         need_replacement   jour_vol  time_en_air  etat_voyant  temp en °C  \
# 438614                 0 2024-06-16          9.0            1       -34.6
# 308132                 0 2024-06-16          9.0            1       -34.6
# 308144                 0 2024-06-16          9.0            1       -34.6
# 329876                 0 2024-06-16          9.0            1       -34.6
# 167492                 0 2024-06-16          9.0            1       -34.6
# 89291                  0 2024-06-16          9.0            1       -34.6
# 329882                 0 2024-06-16          9.0            1       -34.6
# 308138                 0 2024-06-16          9.0            1       -34.6
# 329888                 0 2024-06-16          9.0            1       -34.6
# 89285                  0 2024-06-16          9.0            1       -34.6
# 167498                 0 2024-06-16          9.0            1       -34.6
# 329894                 0 2024-06-16          9.0            1       -34.6
# 186479                 0 2024-06-16          9.0            1       -34.6
# 269                    0 2024-06-16          9.0            1       -34.6
# 167504                 0 2024-06-16          9.0            1       -34.6
# 329900                 0 2024-06-16          9.0            1       -34.6
# 308126                 0 2024-06-16          9.0            1       -34.6
# 263                    0 2024-06-16          9.0            1       -34.6
# 308120                 0 2024-06-16          9.0            1       -34.6
# 329906                 0 2024-06-16          9.0            1       -34.6
# 167510                 0 2024-06-16          9.0            1       -34.6
# 329912                 0 2024-06-16          9.0            1       -34.6
# 89297                  0 2024-06-16          9.0            1       -34.6
# 308150                 0 2024-06-16          9.0            1       -34.6
# 329870                 0 2024-06-16          9.0            1       -34.6
# 167486                 0 2024-06-16          9.0            1       -34.6
# 308180                 0 2024-06-16          9.0            1       -34.6
# 89327                  0 2024-06-16          9.0            1       -34.6
# 329834                 0 2024-06-16          9.0            1       -34.6
# 167468                 0 2024-06-16          9.0            1       -34.6
# 329840                 0 2024-06-16          9.0            1       -34.6
# 89321                  0 2024-06-16          9.0            1       -34.6
# 308174                 0 2024-06-16          9.0            1       -34.6
# 308168                 0 2024-06-16          9.0            1       -34.6
# 329846                 0 2024-06-16          9.0            1       -34.6
# 89315                  0 2024-06-16          9.0            1       -34.6
# 167474                 0 2024-06-16          9.0            1       -34.6
# 329852                 0 2024-06-16          9.0            1       -34.6
# 308162                 0 2024-06-16          9.0            1       -34.6
# 89309                  0 2024-06-16          9.0            1       -34.6
# 329858                 0 2024-06-16          9.0            1       -34.6
# 167480                 0 2024-06-16          9.0            1       -34.6
# 308156                 0 2024-06-16          9.0            1       -34.6
# 329864                 0 2024-06-16          9.0            1       -34.6
#
#         pressure en hPa  vibrations en m/s²  categorie  \
# 438614            836.7               1.176          0
# 308132            836.7               1.176          2
# 308144            836.7               1.176          2
# 329876            836.7               1.176          1
# 167492            836.7               1.176          2
# 89291             836.7               1.176          2
# 329882            836.7               1.176          1
# 308138            836.7               1.176          2
# 329888            836.7               1.176          1
# 89285             836.7               1.176          2
# 167498            836.7               1.176          2
# 329894            836.7               1.176          1
# 186479            836.7               1.176          0
# 269               836.7               1.176          0
# 167504            836.7               1.176          2
# 329900            836.7               1.176          0
# 308126            836.7               1.176          2
# 263               836.7               1.176          0
# 308120            836.7               1.176          2
# 329906            836.7               1.176          0
# 167510            836.7               1.176          2
# 329912            836.7               1.176          0
# 89297             836.7               1.176          2
# 308150            836.7               1.176          2
# 329870            836.7               1.176          1
# 167486            836.7               1.176          2
# 308180            836.7               1.176          2
# 89327             836.7               1.176          2
# 329834            836.7               1.176          1
# 167468            836.7               1.176          2
# 329840            836.7               1.176          1
# 89321             836.7               1.176          2
# 308174            836.7               1.176          2
# 308168            836.7               1.176          2
# 329846            836.7               1.176          1
# 89315             836.7               1.176          2
# 167474            836.7               1.176          2
# 329852            836.7               1.176          1
# 308162            836.7               1.176          2
# 89309             836.7               1.176          2
# 329858            836.7               1.176          1
# 167480            836.7               1.176          2
# 308156            836.7               1.176          2
# 329864            836.7               1.176          1
#
#                                                desc  lifespan  \
# 438614           Système d'approvisionnement en eau   12796.0
# 308132                        Système de navigation   10541.0
# 308144                                   Autopilote   14847.0
# 329876                      Gouvernail de direction   12643.0
# 167492               Système de communication radio   10370.0
# 89291                                Réacteur droit   13626.0
# 329882                    Système de pressurisation   11338.0
# 308138                            Ordinateur de vol   10441.0
# 329888             Système de conditionnement d'air   10343.0
# 89285                               Réacteur gauche   13045.0
# 167498              Système de gestion de carburant   13219.0
# 329894              Système d'extinction d'incendie   11971.0
# 186479           Système d'approvisionnement en eau   12796.0
# 269              Système d'approvisionnement en eau   12796.0
# 167504  Système d'alerte de proximité au sol (GPWS)   10423.0
# 329900                          Éclairage de cabine   12779.0
# 308126                               Réacteur droit   13626.0
# 263                          Éclairage de la cabine   10639.0
# 308120                              Réacteur gauche   13045.0
# 329906                                 Siège pilote   12106.0
# 167510                  Système de commande des gaz   11747.0
# 329912                               Siège copilote   14200.0
# 89297                         Système de navigation   10541.0
# 308150                   Système de contrôle de vol   12580.0
# 329870      Système de contrôle des surfaces de vol   11125.0
# 167486                         Radar météorologique   11923.0
# 308180                  Système de commande des gaz   11747.0
# 89327                Système de communication radio   10370.0
# 329834                           Système anti-givre   14807.0
# 167468                            Ordinateur de vol   10441.0
# 329840                                     Ailerons   10524.0
# 89321                          Radar météorologique   11923.0
# 308174  Système d'alerte de proximité au sol (GPWS)   10423.0
# 308168              Système de gestion de carburant   13219.0
# 329846                                    Empennage   13736.0
# 89315                    Système de contrôle de vol   12580.0
# 167474                                   Autopilote   14847.0
# 329852                                        Flaps   11025.0
# 308162               Système de communication radio   10370.0
# 89309                                    Autopilote   14847.0
# 329858                                     Spoilers   13426.0
# 167480                   Système de contrôle de vol   12580.0
# 308156                         Radar météorologique   11923.0
# 329864                                       Freins   11015.0
#
#         taux_usure_actuel     cout
# 438614          21.509700   4701.0
# 308132          16.730575  16514.0
# 308144          42.033525  19362.0
# 329876          31.348225  12059.0
# 167492          26.167750  19214.0
# 89291           50.111950  17559.0
# 329882           5.750350  13233.0
# 308138           6.653075  16047.0
# 329888           2.155725  13453.0
# 89285           53.308375  15552.0
# 167498           2.441425  18351.0
# 329894          49.257825  10109.0
# 186479          21.509700   4701.0
# 269             21.509700   4701.0
# 167504          31.011725  18680.0
# 329900          48.378425   4788.0
# 308126          50.111950  17559.0
# 263             50.677925   4965.0
# 308120          53.308375  15552.0
# 329906          19.857950   2151.0
# 167510          26.801025  18091.0
# 329912          40.625000   3722.0
# 89297           16.730575  16514.0
# 308150           5.543500  19492.0
# 329870          10.334375  12191.0
# 167486          22.154225  17567.0
# 308180          26.801025  18091.0
# 89327           26.167750  19214.0
# 329834          31.810525  13366.0
# 167468           6.653075  16047.0
# 329840          50.829300  10290.0
# 89321           22.154225  17567.0
# 308174          31.011725  18680.0
# 308168           2.441425  18351.0
# 329846          50.240200  10528.0
# 89315            5.543500  19492.0
# 167474          42.033525  19362.0
# 329852           5.746875  14480.0
# 308162          26.167750  19214.0
# 89309           42.033525  19362.0
# 329858           4.496950  12456.0
# 167480           5.543500  19492.0
# 308156          22.154225  17567.0
# 329864          29.816125  12664.0

# %%
data[data['ref_compo'] == 'REAE170-E170_6353-0']
# Out:
#           id_aero            ref_compo  usure_cumulée measure_day  \
# 0       E170_6353  REAE170-E170_6353-0           53.0  2024-06-01
# 1       E170_6353  REAE170-E170_6353-0           53.0  2024-06-01
# 2       E170_6353  REAE170-E170_6353-0           53.0  2024-06-01
# 3       E170_6353  REAE170-E170_6353-0           53.0  2024-06-01
# 4       E170_6353  REAE170-E170_6353-0           53.0  2024-06-01
# 5       E170_6353  REAE170-E170_6353-0           53.0  2024-06-01
# 89280   E170_6353  REAE170-E170_6353-0           54.0  2024-06-04
# 89281   E170_6353  REAE170-E170_6353-0           54.0  2024-06-04
# 89282   E170_6353  REAE170-E170_6353-0           54.0  2024-06-04
# 89283   E170_6353  REAE170-E170_6353-0           54.0  2024-06-04
# 89284   E170_6353  REAE170-E170_6353-0           54.0  2024-06-04
# 89285   E170_6353  REAE170-E170_6353-0           54.0  2024-06-04
# 167445  E170_6353  REAE170-E170_6353-0           54.0  2024-06-06
# 167446  E170_6353  REAE170-E170_6353-0           54.0  2024-06-06
# 167447  E170_6353  REAE170-E170_6353-0           54.0  2024-06-06
# 167448  E170_6353  REAE170-E170_6353-0           54.0  2024-06-06
# 167449  E170_6353  REAE170-E170_6353-0           54.0  2024-06-06
# 167450  E170_6353  REAE170-E170_6353-0           54.0  2024-06-06
# 186210  E170_6353  REAE170-E170_6353-0           56.0  2024-06-07
# 186211  E170_6353  REAE170-E170_6353-0           56.0  2024-06-07
# 186212  E170_6353  REAE170-E170_6353-0           56.0  2024-06-07
# 186213  E170_6353  REAE170-E170_6353-0           56.0  2024-06-07
# 186214  E170_6353  REAE170-E170_6353-0           56.0  2024-06-07
# 186215  E170_6353  REAE170-E170_6353-0           56.0  2024-06-07
# 308115  E170_6353  REAE170-E170_6353-0           57.0  2024-06-11
# 308116  E170_6353  REAE170-E170_6353-0           57.0  2024-06-11
# 308117  E170_6353  REAE170-E170_6353-0           57.0  2024-06-11
# 308118  E170_6353  REAE170-E170_6353-0           57.0  2024-06-11
# 308119  E170_6353  REAE170-E170_6353-0           57.0  2024-06-11
# 308120  E170_6353  REAE170-E170_6353-0           57.0  2024-06-11
# 329715  E170_6353  REAE170-E170_6353-0           58.0  2024-06-12
# 329716  E170_6353  REAE170-E170_6353-0           58.0  2024-06-12
# 329717  E170_6353  REAE170-E170_6353-0           58.0  2024-06-12
# 329718  E170_6353  REAE170-E170_6353-0           58.0  2024-06-12
# 329719  E170_6353  REAE170-E170_6353-0           58.0  2024-06-12
# 329720  E170_6353  REAE170-E170_6353-0           58.0  2024-06-12
# 438345  E170_6353  REAE170-E170_6353-0           59.0  2024-06-16
# 438346  E170_6353  REAE170-E170_6353-0           59.0  2024-06-16
# 438347  E170_6353  REAE170-E170_6353-0           59.0  2024-06-16
# 438348  E170_6353  REAE170-E170_6353-0           59.0  2024-06-16
# 438349  E170_6353  REAE170-E170_6353-0           59.0  2024-06-16
# 438350  E170_6353  REAE170-E170_6353-0           59.0  2024-06-16
#
#         need_replacement   jour_vol  time_en_air  etat_voyant  temp en °C  \
# 0                      0 2024-06-04          6.9            0        -2.2
# 1                      0 2024-06-06          1.8            0         2.9
# 2                      0 2024-06-07          9.9            1       -12.4
# 3                      0 2024-06-11          6.7            0         1.7
# 4                      0 2024-06-12          6.9            0         3.7
# 5                      0 2024-06-16          9.0            1       -34.6
# 89280                  0 2024-06-04          6.9            0        -2.2
# 89281                  0 2024-06-06          1.8            0         2.9
# 89282                  0 2024-06-07          9.9            1       -12.4
# 89283                  0 2024-06-11          6.7            0         1.7
# 89284                  0 2024-06-12          6.9            0         3.7
# 89285                  0 2024-06-16          9.0            1       -34.6
# 167445                 0 2024-06-04          6.9            0        -2.2
# 167446                 0 2024-06-06          1.8            0         2.9
# 167447                 0 2024-06-07          9.9            1       -12.4
# 167448                 0 2024-06-11          6.7            0         1.7
# 167449                 0 2024-06-12          6.9            0         3.7
# 167450                 0 2024-06-16          9.0            1       -34.6
# 186210                 0 2024-06-04          6.9            0        -2.2
# 186211                 0 2024-06-06          1.8            0         2.9
# 186212                 0 2024-06-07          9.9            1       -12.4
# 186213                 0 2024-06-11          6.7            0         1.7
# 186214                 0 2024-06-12          6.9            0         3.7
# 186215                 0 2024-06-16          9.0            1       -34.6
# 308115                 0 2024-06-04          6.9            0        -2.2
# 308116                 0 2024-06-06          1.8            0         2.9
# 308117                 0 2024-06-07          9.9            1       -12.4
# 308118                 0 2024-06-11          6.7            0         1.7
# 308119                 0 2024-06-12          6.9            0         3.7
# 308120                 0 2024-06-16          9.0            1       -34.6
# 329715                 0 2024-06-04          6.9            0        -2.2
# 329716                 0 2024-06-06          1.8            0         2.9
# 329717                 0 2024-06-07          9.9            1       -12.4
# 329718                 0 2024-06-11          6.7            0         1.7
# 329719                 0 2024-06-12          6.9            0         3.7
# 329720                 0 2024-06-16          9.0            1       -34.6
# 438345                 0 2024-06-04          6.9            0        -2.2
# 438346                 0 2024-06-06          1.8            0         2.9
# 438347                 0 2024-06-07          9.9            1       -12.4
# 438348                 0 2024-06-11          6.7            0         1.7
# 438349                 0 2024-06-12          6.9            0         3.7
# 438350                 0 2024-06-16          9.0            1       -34.6
#
#         pressure en hPa  vibrations en m/s²  categorie             desc  \
# 0                 980.7               1.235          2  Réacteur gauche
# 1                 953.5               0.942          2  Réacteur gauche
# 2                 918.2               3.568          2  Réacteur gauche
# 3                 944.9               3.377          2  Réacteur gauche
# 4                 984.5               4.178          2  Réacteur gauche
# 5                 836.7               1.176          2  Réacteur gauche
# 89280             980.7               1.235          2  Réacteur gauche
# 89281             953.5               0.942          2  Réacteur gauche
# 89282             918.2               3.568          2  Réacteur gauche
# 89283             944.9               3.377          2  Réacteur gauche
# 89284             984.5               4.178          2  Réacteur gauche
# 89285             836.7               1.176          2  Réacteur gauche
# 167445            980.7               1.235          2  Réacteur gauche
# 167446            953.5               0.942          2  Réacteur gauche
# 167447            918.2               3.568          2  Réacteur gauche
# 167448            944.9               3.377          2  Réacteur gauche
# 167449            984.5               4.178          2  Réacteur gauche
# 167450            836.7               1.176          2  Réacteur gauche
# 186210            980.7               1.235          2  Réacteur gauche
# 186211            953.5               0.942          2  Réacteur gauche
# 186212            918.2               3.568          2  Réacteur gauche
# 186213            944.9               3.377          2  Réacteur gauche
# 186214            984.5               4.178          2  Réacteur gauche
# 186215            836.7               1.176          2  Réacteur gauche
# 308115            980.7               1.235          2  Réacteur gauche
# 308116            953.5               0.942          2  Réacteur gauche
# 308117            918.2               3.568          2  Réacteur gauche
# 308118            944.9               3.377          2  Réacteur gauche
# 308119            984.5               4.178          2  Réacteur gauche
# 308120            836.7               1.176          2  Réacteur gauche
# 329715            980.7               1.235          2  Réacteur gauche
# 329716            953.5               0.942          2  Réacteur gauche
# 329717            918.2               3.568          2  Réacteur gauche
# 329718            944.9               3.377          2  Réacteur gauche
# 329719            984.5               4.178          2  Réacteur gauche
# 329720            836.7               1.176          2  Réacteur gauche
# 438345            980.7               1.235          2  Réacteur gauche
# 438346            953.5               0.942          2  Réacteur gauche
# 438347            918.2               3.568          2  Réacteur gauche
# 438348            944.9               3.377          2  Réacteur gauche
# 438349            984.5               4.178          2  Réacteur gauche
# 438350            836.7               1.176          2  Réacteur gauche
#
#         lifespan  taux_usure_actuel     cout
# 0        13045.0          53.308375  15552.0
# 1        13045.0          53.308375  15552.0
# 2        13045.0          53.308375  15552.0
# 3        13045.0          53.308375  15552.0
# 4        13045.0          53.308375  15552.0
# 5        13045.0          53.308375  15552.0
# 89280    13045.0          53.308375  15552.0
# 89281    13045.0          53.308375  15552.0
# 89282    13045.0          53.308375  15552.0
# 89283    13045.0          53.308375  15552.0
# 89284    13045.0          53.308375  15552.0
# 89285    13045.0          53.308375  15552.0
# 167445   13045.0          53.308375  15552.0
# 167446   13045.0          53.308375  15552.0
# 167447   13045.0          53.308375  15552.0
# 167448   13045.0          53.308375  15552.0
# 167449   13045.0          53.308375  15552.0
# 167450   13045.0          53.308375  15552.0
# 186210   13045.0          53.308375  15552.0
# 186211   13045.0          53.308375  15552.0
# 186212   13045.0          53.308375  15552.0
# 186213   13045.0          53.308375  15552.0
# 186214   13045.0          53.308375  15552.0
# 186215   13045.0          53.308375  15552.0
# 308115   13045.0          53.308375  15552.0
# 308116   13045.0          53.308375  15552.0
# 308117   13045.0          53.308375  15552.0
# 308118   13045.0          53.308375  15552.0
# 308119   13045.0          53.308375  15552.0
# 308120   13045.0          53.308375  15552.0
# 329715   13045.0          53.308375  15552.0
# 329716   13045.0          53.308375  15552.0
# 329717   13045.0          53.308375  15552.0
# 329718   13045.0          53.308375  15552.0
# 329719   13045.0          53.308375  15552.0
# 329720   13045.0          53.308375  15552.0
# 438345   13045.0          53.308375  15552.0
# 438346   13045.0          53.308375  15552.0
# 438347   13045.0          53.308375  15552.0
# 438348   13045.0          53.308375  15552.0
# 438349   13045.0          53.308375  15552.0
# 438350   13045.0          53.308375  15552.0

# %% [markdown]
# # ici je choisi de masquer les dates inférieures à 2024-05-01 volontairement pour eviter les variations inexpliquées des taux d'usures

# %%
#data = data[data['measure_day'] >= '2024-05-01']

# %% [markdown]
# # ici je choisi de ranger les taux d'usure par catégories de composants :

# %%
data_categorie_0 = pd.DataFrame(data[data['categorie'] == 0].groupby('measure_day')['usure_cumulée'].mean())
data_categorie_1 = pd.DataFrame(data[data['categorie'] == 1].groupby('measure_day')['usure_cumulée'].mean())
data_categorie_2 = pd.DataFrame(data[data['categorie'] == 2].groupby('measure_day')['usure_cumulée'].mean())

# %%
data_list = [data_categorie_0, data_categorie_1, data_categorie_2]
plt.figure(figsize=(25, 10))

for i, data_categorie in enumerate(data_list):
    if 'usure_cumulée' in data_categorie.columns:
        plt.plot(data_categorie.index, data_categorie['usure_cumulée'], marker='o', label=f'Catégorie {i}')
    else:
        print(f"Le DataFrame de la catégorie {i} ne contient pas la colonne 'usure_cumulée'")

plt.xlabel('Measure_day')
plt.ylabel('Usure cumulée %')
plt.title('Usure cumulée moyenne des composants par catégorie')
plt.legend()
plt.grid(True)

# Afficher le graphique
plt.show()

# %%
"""
une prediction du taux d'usure cumulée peut être réalisée par catéorie de composants.
avec une regression linéraire multiple.
Par ailleurs un modlèle de régression linéaire peut être utilisé pour chacun des composants
    
    
"""
# Out:
# "\nune prediction du taux d'usure cumulée peut être réalisée par catéorie de composants.\navec une regression linéraire multiple.\nPar ailleurs un modlèle de régression linéaire peut être utilisé pour chacun des composants\n    \n    \n"

# %%
def usure_composant(data, ref_compo):
    """
    Fonction permettant de réaliser un tracé l'usure cumulée d'un composant.

    Parameters:
    data (DataFrame): DataFrame contenant les données de mesure.
    ref_compo (str): Référence du composant à tracer.
    
    """
    if ref_compo not in data['ref_compo'].values:
        print(f"Référence du composant {ref_compo} non trouvée dans les données.")
        return
    compo_data = data[data['ref_compo'] == ref_compo]

    if compo_data.empty:
        print(f"Aucune donnée trouvée pour la référence du composant {ref_compo}.")
        return
    plt.figure(figsize=(25, 10))
    plt.plot(compo_data['measure_day'], compo_data['usure_cumulée'], label=compo_data['desc'].iloc[0])
    plt.xlabel('Jour de mesure')
    plt.ylabel('Usure cumulée (%)')
    plt.title(f'Usure cumulée pour le composant {ref_compo}')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
def comparaison_usure(data, ref_compo_1, ref_compo_2):
    """
    Fonction permettant de réaliser un tracé de la usure cumulée de deux composants.

    Parameters:
    data (DataFrame): DataFrame contenant les données de mesure.
    ref_compo_1 (str): Référence du premier composant à tracer.
    ref_compo_2 (str): Référence du deuxième composant à tracer.
    """

    if ref_compo_1 not in data['ref_compo'].values:
        print(f"Référence du composant {ref_compo_1} non trouvée dans les données.")
        return
    if ref_compo_2 not in data['ref_compo'].values:
        print(f"Référence du composant {ref_compo_2} non trouvée dans les données.")
        return
    compo_data_1 = data[data['ref_compo'] == ref_compo_1]
    compo_data_2 = data[data['ref_compo'] == ref_compo_2]

    if compo_data_1.empty:
        print(f"Aucune donnée trouvée pour la référence du composant {ref_compo_1}.")
        return
    if compo_data_2.empty:
        print(f"Aucune donnée trouvée pour la référence du composant {ref_compo_2}.")
        return

    plt.figure(figsize=(25, 10))
    plt.plot(compo_data_1['measure_day'], compo_data_1['usure_cumulée'], label=compo_data_1['desc'].iloc[0])
    plt.plot(compo_data_2['measure_day'], compo_data_2['usure_cumulée'], label=compo_data_2['desc'].iloc[0])
    plt.legend()
    plt.grid(True)
    plt.xlabel('Jour de mesure')
    plt.ylabel('Usure cumulée (%)')
    plt.title(f'Usure cumulée de {ref_compo_1} et {ref_compo_2}')
    plt.show()

# %%
data['ref_compo'].to_list()
# Out:
# ['REAE170-E170_6353-0',
#  'REAE170-E170_6353-0',
#  'REAE170-E170_6353-0',
#  'REAE170-E170_6353-0',
#  'REAE170-E170_6353-0',
#  'REAE170-E170_6353-0',
#  'REAE170-E170_6353-1',
#  'REAE170-E170_6353-1',
#  'REAE170-E170_6353-1',
#  'REAE170-E170_6353-1',
#  'REAE170-E170_6353-1',
#  'REAE170-E170_6353-1',
#  'SYSE170-E170_6353-2',
#  'SYSE170-E170_6353-2',
#  'SYSE170-E170_6353-2',
#  'SYSE170-E170_6353-2',
#  'SYSE170-E170_6353-2',
#  'SYSE170-E170_6353-2',
#  'ORDE170-E170_6353-3',
#  'ORDE170-E170_6353-3',
#  'ORDE170-E170_6353-3',
#  'ORDE170-E170_6353-3',
#  'ORDE170-E170_6353-3',
#  'ORDE170-E170_6353-3',
#  'AUTE170-E170_6353-4',
#  'AUTE170-E170_6353-4',
#  'AUTE170-E170_6353-4',
#  'AUTE170-E170_6353-4',
#  'AUTE170-E170_6353-4',
#  'AUTE170-E170_6353-4',
#  'SYSE170-E170_6353-5',
#  'SYSE170-E170_6353-5',
#  'SYSE170-E170_6353-5',
#  'SYSE170-E170_6353-5',
#  'SYSE170-E170_6353-5',
#  'SYSE170-E170_6353-5',
#  'RADE170-E170_6353-6',
#  'RADE170-E170_6353-6',
#  'RADE170-E170_6353-6',
#  'RADE170-E170_6353-6',
#  'RADE170-E170_6353-6',
#  'RADE170-E170_6353-6',
#  'SYSE170-E170_6353-7',
#  'SYSE170-E170_6353-7',
#  'SYSE170-E170_6353-7',
#  'SYSE170-E170_6353-7',
#  'SYSE170-E170_6353-7',
#  'SYSE170-E170_6353-7',
#  'SYSE170-E170_6353-8',
#  'SYSE170-E170_6353-8',
#  'SYSE170-E170_6353-8',
#  'SYSE170-E170_6353-8',
#  'SYSE170-E170_6353-8',
#  'SYSE170-E170_6353-8',
#  'SYSE170-E170_6353-9',
#  'SYSE170-E170_6353-9',
#  'SYSE170-E170_6353-9',
#  'SYSE170-E170_6353-9',
#  'SYSE170-E170_6353-9',
#  'SYSE170-E170_6353-9',
#  'SYSE170-E170_6353-10',
#  'SYSE170-E170_6353-10',
#  'SYSE170-E170_6353-10',
#  'SYSE170-E170_6353-10',
#  'SYSE170-E170_6353-10',
#  'SYSE170-E170_6353-10',
#  'UNIE170-E170_6353-11',
#  'UNIE170-E170_6353-11',
#  'UNIE170-E170_6353-11',
#  'UNIE170-E170_6353-11',
#  'UNIE170-E170_6353-11',
#  'UNIE170-E170_6353-11',
#  'SYSE170-E170_6353-12',
#  'SYSE170-E170_6353-12',
#  'SYSE170-E170_6353-12',
#  'SYSE170-E170_6353-12',
#  'SYSE170-E170_6353-12',
#  'SYSE170-E170_6353-12',
#  'SYSE170-E170_6353-13',
#  'SYSE170-E170_6353-13',
#  'SYSE170-E170_6353-13',
#  'SYSE170-E170_6353-13',
#  'SYSE170-E170_6353-13',
#  'SYSE170-E170_6353-13',
#  'SYSE170-E170_6353-14',
#  'SYSE170-E170_6353-14',
#  'SYSE170-E170_6353-14',
#  'SYSE170-E170_6353-14',
#  'SYSE170-E170_6353-14',
#  'SYSE170-E170_6353-14',
#  'SYSE170-E170_6353-15',
#  'SYSE170-E170_6353-15',
#  'SYSE170-E170_6353-15',
#  'SYSE170-E170_6353-15',
#  'SYSE170-E170_6353-15',
#  'SYSE170-E170_6353-15',
#  'GENE170-E170_6353-16',
#  'GENE170-E170_6353-16',
#  'GENE170-E170_6353-16',
#  'GENE170-E170_6353-16',
#  'GENE170-E170_6353-16',
#  'GENE170-E170_6353-16',
#  'TRAE170-E170_6353-17',
#  'TRAE170-E170_6353-17',
#  'TRAE170-E170_6353-17',
#  'TRAE170-E170_6353-17',
#  'TRAE170-E170_6353-17',
#  'TRAE170-E170_6353-17',
#  'TRAE170-E170_6353-18',
#  'TRAE170-E170_6353-18',
#  'TRAE170-E170_6353-18',
#  'TRAE170-E170_6353-18',
#  'TRAE170-E170_6353-18',
#  'TRAE170-E170_6353-18',
#  'SYSE170-E170_6353-19',
#  'SYSE170-E170_6353-19',
#  'SYSE170-E170_6353-19',
#  'SYSE170-E170_6353-19',
#  'SYSE170-E170_6353-19',
#  'SYSE170-E170_6353-19',
#  'AILE170-E170_6353-20',
#  'AILE170-E170_6353-20',
#  'AILE170-E170_6353-20',
#  'AILE170-E170_6353-20',
#  'AILE170-E170_6353-20',
#  'AILE170-E170_6353-20',
#  'EMPE170-E170_6353-21',
#  'EMPE170-E170_6353-21',
#  'EMPE170-E170_6353-21',
#  'EMPE170-E170_6353-21',
#  'EMPE170-E170_6353-21',
#  'EMPE170-E170_6353-21',
#  'FLAE170-E170_6353-22',
#  'FLAE170-E170_6353-22',
#  'FLAE170-E170_6353-22',
#  'FLAE170-E170_6353-22',
#  'FLAE170-E170_6353-22',
#  'FLAE170-E170_6353-22',
#  'SPOE170-E170_6353-23',
#  'SPOE170-E170_6353-23',
#  'SPOE170-E170_6353-23',
#  'SPOE170-E170_6353-23',
#  'SPOE170-E170_6353-23',
#  'SPOE170-E170_6353-23',
#  'FREE170-E170_6353-24',
#  'FREE170-E170_6353-24',
#  'FREE170-E170_6353-24',
#  'FREE170-E170_6353-24',
#  'FREE170-E170_6353-24',
#  'FREE170-E170_6353-24',
#  'SYSE170-E170_6353-25',
#  'SYSE170-E170_6353-25',
#  'SYSE170-E170_6353-25',
#  'SYSE170-E170_6353-25',
#  'SYSE170-E170_6353-25',
#  'SYSE170-E170_6353-25',
#  'GOUE170-E170_6353-26',
#  'GOUE170-E170_6353-26',
#  'GOUE170-E170_6353-26',
#  'GOUE170-E170_6353-26',
#  'GOUE170-E170_6353-26',
#  'GOUE170-E170_6353-26',
#  'SYSE170-E170_6353-27',
#  'SYSE170-E170_6353-27',
#  'SYSE170-E170_6353-27',
#  'SYSE170-E170_6353-27',
#  'SYSE170-E170_6353-27',
#  'SYSE170-E170_6353-27',
#  'SYSE170-E170_6353-28',
#  'SYSE170-E170_6353-28',
#  'SYSE170-E170_6353-28',
#  'SYSE170-E170_6353-28',
#  'SYSE170-E170_6353-28',
#  'SYSE170-E170_6353-28',
#  'SYSE170-E170_6353-29',
#  'SYSE170-E170_6353-29',
#  'SYSE170-E170_6353-29',
#  'SYSE170-E170_6353-29',
#  'SYSE170-E170_6353-29',
#  'SYSE170-E170_6353-29',
#  'ECLE170-E170_6353-30',
#  'ECLE170-E170_6353-30',
#  'ECLE170-E170_6353-30',
#  'ECLE170-E170_6353-30',
#  'ECLE170-E170_6353-30',
#  'ECLE170-E170_6353-30',
#  'SIEE170-E170_6353-31',
#  'SIEE170-E170_6353-31',
#  'SIEE170-E170_6353-31',
#  'SIEE170-E170_6353-31',
#  'SIEE170-E170_6353-31',
#  'SIEE170-E170_6353-31',
#  'SIEE170-E170_6353-32',
#  'SIEE170-E170_6353-32',
#  'SIEE170-E170_6353-32',
#  'SIEE170-E170_6353-32',
#  'SIEE170-E170_6353-32',
#  'SIEE170-E170_6353-32',
#  'SYSE170-E170_6353-33',
#  'SYSE170-E170_6353-33',
#  'SYSE170-E170_6353-33',
#  'SYSE170-E170_6353-33',
#  'SYSE170-E170_6353-33',
#  'SYSE170-E170_6353-33',
#  'SYSE170-E170_6353-34',
#  'SYSE170-E170_6353-34',
#  'SYSE170-E170_6353-34',
#  'SYSE170-E170_6353-34',
#  'SYSE170-E170_6353-34',
#  'SYSE170-E170_6353-34',
#  'TOIE170-E170_6353-35',
#  'TOIE170-E170_6353-35',
#  'TOIE170-E170_6353-35',
#  'TOIE170-E170_6353-35',
#  'TOIE170-E170_6353-35',
#  'TOIE170-E170_6353-35',
#  'SYSE170-E170_6353-36',
#  'SYSE170-E170_6353-36',
#  'SYSE170-E170_6353-36',
#  'SYSE170-E170_6353-36',
#  'SYSE170-E170_6353-36',
#  'SYSE170-E170_6353-36',
#  'DETE170-E170_6353-37',
#  'DETE170-E170_6353-37',
#  'DETE170-E170_6353-37',
#  'DETE170-E170_6353-37',
#  'DETE170-E170_6353-37',
#  'DETE170-E170_6353-37',
#  'ECLE170-E170_6353-38',
#  'ECLE170-E170_6353-38',
#  'ECLE170-E170_6353-38',
#  'ECLE170-E170_6353-38',
#  'ECLE170-E170_6353-38',
#  'ECLE170-E170_6353-38',
#  'PORE170-E170_6353-39',
#  'PORE170-E170_6353-39',
#  'PORE170-E170_6353-39',
#  'PORE170-E170_6353-39',
#  'PORE170-E170_6353-39',
#  'PORE170-E170_6353-39',
#  'SYSE170-E170_6353-40',
#  'SYSE170-E170_6353-40',
#  'SYSE170-E170_6353-40',
#  'SYSE170-E170_6353-40',
#  'SYSE170-E170_6353-40',
#  'SYSE170-E170_6353-40',
#  'PORE170-E170_6353-41',
#  'PORE170-E170_6353-41',
#  'PORE170-E170_6353-41',
#  'PORE170-E170_6353-41',
#  'PORE170-E170_6353-41',
#  'PORE170-E170_6353-41',
#  'HUBE170-E170_6353-42',
#  'HUBE170-E170_6353-42',
#  'HUBE170-E170_6353-42',
#  'HUBE170-E170_6353-42',
#  'HUBE170-E170_6353-42',
#  'HUBE170-E170_6353-42',
#  'ECLE170-E170_6353-43',
#  'ECLE170-E170_6353-43',
#  'ECLE170-E170_6353-43',
#  'ECLE170-E170_6353-43',
#  'ECLE170-E170_6353-43',
#  'ECLE170-E170_6353-43',
#  'SYSE170-E170_6353-44',
#  'SYSE170-E170_6353-44',
#  'SYSE170-E170_6353-44',
#  'SYSE170-E170_6353-44',
#  'SYSE170-E170_6353-44',
#  'SYSE170-E170_6353-44',
#  'REAB767-B767_2803-0',
#  'REAB767-B767_2803-0',
#  'REAB767-B767_2803-0',
#  'REAB767-B767_2803-0',
#  'REAB767-B767_2803-0',
#  'REAB767-B767_2803-0',
#  'REAB767-B767_2803-1',
#  'REAB767-B767_2803-1',
#  'REAB767-B767_2803-1',
#  'REAB767-B767_2803-1',
#  'REAB767-B767_2803-1',
#  'REAB767-B767_2803-1',
#  'SYSB767-B767_2803-2',
#  'SYSB767-B767_2803-2',
#  'SYSB767-B767_2803-2',
#  'SYSB767-B767_2803-2',
#  'SYSB767-B767_2803-2',
#  'SYSB767-B767_2803-2',
#  'ORDB767-B767_2803-3',
#  'ORDB767-B767_2803-3',
#  'ORDB767-B767_2803-3',
#  'ORDB767-B767_2803-3',
#  'ORDB767-B767_2803-3',
#  'ORDB767-B767_2803-3',
#  'AUTB767-B767_2803-4',
#  'AUTB767-B767_2803-4',
#  'AUTB767-B767_2803-4',
#  'AUTB767-B767_2803-4',
#  'AUTB767-B767_2803-4',
#  'AUTB767-B767_2803-4',
#  'SYSB767-B767_2803-5',
#  'SYSB767-B767_2803-5',
#  'SYSB767-B767_2803-5',
#  'SYSB767-B767_2803-5',
#  'SYSB767-B767_2803-5',
#  'SYSB767-B767_2803-5',
#  'RADB767-B767_2803-6',
#  'RADB767-B767_2803-6',
#  'RADB767-B767_2803-6',
#  'RADB767-B767_2803-6',
#  'RADB767-B767_2803-6',
#  'RADB767-B767_2803-6',
#  'SYSB767-B767_2803-7',
#  'SYSB767-B767_2803-7',
#  'SYSB767-B767_2803-7',
#  'SYSB767-B767_2803-7',
#  'SYSB767-B767_2803-7',
#  'SYSB767-B767_2803-7',
#  'SYSB767-B767_2803-8',
#  'SYSB767-B767_2803-8',
#  'SYSB767-B767_2803-8',
#  'SYSB767-B767_2803-8',
#  'SYSB767-B767_2803-8',
#  'SYSB767-B767_2803-8',
#  'SYSB767-B767_2803-9',
#  'SYSB767-B767_2803-9',
#  'SYSB767-B767_2803-9',
#  'SYSB767-B767_2803-9',
#  'SYSB767-B767_2803-9',
#  'SYSB767-B767_2803-9',
#  'SYSB767-B767_2803-10',
#  'SYSB767-B767_2803-10',
#  'SYSB767-B767_2803-10',
#  'SYSB767-B767_2803-10',
#  'SYSB767-B767_2803-10',
#  'SYSB767-B767_2803-10',
#  'UNIB767-B767_2803-11',
#  'UNIB767-B767_2803-11',
#  'UNIB767-B767_2803-11',
#  'UNIB767-B767_2803-11',
#  'UNIB767-B767_2803-11',
#  'UNIB767-B767_2803-11',
#  'SYSB767-B767_2803-12',
#  'SYSB767-B767_2803-12',
#  'SYSB767-B767_2803-12',
#  'SYSB767-B767_2803-12',
#  'SYSB767-B767_2803-12',
#  'SYSB767-B767_2803-12',
#  'SYSB767-B767_2803-13',
#  'SYSB767-B767_2803-13',
#  'SYSB767-B767_2803-13',
#  'SYSB767-B767_2803-13',
#  'SYSB767-B767_2803-13',
#  'SYSB767-B767_2803-13',
#  'SYSB767-B767_2803-14',
#  'SYSB767-B767_2803-14',
#  'SYSB767-B767_2803-14',
#  'SYSB767-B767_2803-14',
#  'SYSB767-B767_2803-14',
#  'SYSB767-B767_2803-14',
#  'SYSB767-B767_2803-15',
#  'SYSB767-B767_2803-15',
#  'SYSB767-B767_2803-15',
#  'SYSB767-B767_2803-15',
#  'SYSB767-B767_2803-15',
#  'SYSB767-B767_2803-15',
#  'GENB767-B767_2803-16',
#  'GENB767-B767_2803-16',
#  'GENB767-B767_2803-16',
#  'GENB767-B767_2803-16',
#  'GENB767-B767_2803-16',
#  'GENB767-B767_2803-16',
#  'TRAB767-B767_2803-17',
#  'TRAB767-B767_2803-17',
#  'TRAB767-B767_2803-17',
#  'TRAB767-B767_2803-17',
#  'TRAB767-B767_2803-17',
#  'TRAB767-B767_2803-17',
#  'TRAB767-B767_2803-18',
#  'TRAB767-B767_2803-18',
#  'TRAB767-B767_2803-18',
#  'TRAB767-B767_2803-18',
#  'TRAB767-B767_2803-18',
#  'TRAB767-B767_2803-18',
#  'SYSB767-B767_2803-19',
#  'SYSB767-B767_2803-19',
#  'SYSB767-B767_2803-19',
#  'SYSB767-B767_2803-19',
#  'SYSB767-B767_2803-19',
#  'SYSB767-B767_2803-19',
#  'AILB767-B767_2803-20',
#  'AILB767-B767_2803-20',
#  'AILB767-B767_2803-20',
#  'AILB767-B767_2803-20',
#  'AILB767-B767_2803-20',
#  'AILB767-B767_2803-20',
#  'EMPB767-B767_2803-21',
#  'EMPB767-B767_2803-21',
#  'EMPB767-B767_2803-21',
#  'EMPB767-B767_2803-21',
#  'EMPB767-B767_2803-21',
#  'EMPB767-B767_2803-21',
#  'FLAB767-B767_2803-22',
#  'FLAB767-B767_2803-22',
#  'FLAB767-B767_2803-22',
#  'FLAB767-B767_2803-22',
#  'FLAB767-B767_2803-22',
#  'FLAB767-B767_2803-22',
#  'SPOB767-B767_2803-23',
#  'SPOB767-B767_2803-23',
#  'SPOB767-B767_2803-23',
#  'SPOB767-B767_2803-23',
#  'SPOB767-B767_2803-23',
#  'SPOB767-B767_2803-23',
#  'FREB767-B767_2803-24',
#  'FREB767-B767_2803-24',
#  'FREB767-B767_2803-24',
#  'FREB767-B767_2803-24',
#  'FREB767-B767_2803-24',
#  'FREB767-B767_2803-24',
#  'SYSB767-B767_2803-25',
#  'SYSB767-B767_2803-25',
#  'SYSB767-B767_2803-25',
#  'SYSB767-B767_2803-25',
#  'SYSB767-B767_2803-25',
#  'SYSB767-B767_2803-25',
#  'GOUB767-B767_2803-26',
#  'GOUB767-B767_2803-26',
#  'GOUB767-B767_2803-26',
#  'GOUB767-B767_2803-26',
#  'GOUB767-B767_2803-26',
#  'GOUB767-B767_2803-26',
#  'SYSB767-B767_2803-27',
#  'SYSB767-B767_2803-27',
#  'SYSB767-B767_2803-27',
#  'SYSB767-B767_2803-27',
#  'SYSB767-B767_2803-27',
#  'SYSB767-B767_2803-27',
#  'SYSB767-B767_2803-28',
#  'SYSB767-B767_2803-28',
#  'SYSB767-B767_2803-28',
#  'SYSB767-B767_2803-28',
#  'SYSB767-B767_2803-28',
#  'SYSB767-B767_2803-28',
#  'SYSB767-B767_2803-29',
#  'SYSB767-B767_2803-29',
#  'SYSB767-B767_2803-29',
#  'SYSB767-B767_2803-29',
#  'SYSB767-B767_2803-29',
#  'SYSB767-B767_2803-29',
#  'ECLB767-B767_2803-30',
#  'ECLB767-B767_2803-30',
#  'ECLB767-B767_2803-30',
#  'ECLB767-B767_2803-30',
#  'ECLB767-B767_2803-30',
#  'ECLB767-B767_2803-30',
#  'SIEB767-B767_2803-31',
#  'SIEB767-B767_2803-31',
#  'SIEB767-B767_2803-31',
#  'SIEB767-B767_2803-31',
#  'SIEB767-B767_2803-31',
#  'SIEB767-B767_2803-31',
#  'SIEB767-B767_2803-32',
#  'SIEB767-B767_2803-32',
#  'SIEB767-B767_2803-32',
#  'SIEB767-B767_2803-32',
#  'SIEB767-B767_2803-32',
#  'SIEB767-B767_2803-32',
#  'SYSB767-B767_2803-33',
#  'SYSB767-B767_2803-33',
#  'SYSB767-B767_2803-33',
#  'SYSB767-B767_2803-33',
#  'SYSB767-B767_2803-33',
#  'SYSB767-B767_2803-33',
#  'SYSB767-B767_2803-34',
#  'SYSB767-B767_2803-34',
#  'SYSB767-B767_2803-34',
#  'SYSB767-B767_2803-34',
#  'SYSB767-B767_2803-34',
#  'SYSB767-B767_2803-34',
#  'TOIB767-B767_2803-35',
#  'TOIB767-B767_2803-35',
#  'TOIB767-B767_2803-35',
#  'TOIB767-B767_2803-35',
#  'TOIB767-B767_2803-35',
#  'TOIB767-B767_2803-35',
#  'SYSB767-B767_2803-36',
#  'SYSB767-B767_2803-36',
#  'SYSB767-B767_2803-36',
#  'SYSB767-B767_2803-36',
#  'SYSB767-B767_2803-36',
#  'SYSB767-B767_2803-36',
#  'DETB767-B767_2803-37',
#  'DETB767-B767_2803-37',
#  'DETB767-B767_2803-37',
#  'DETB767-B767_2803-37',
#  'DETB767-B767_2803-37',
#  'DETB767-B767_2803-37',
#  'ECLB767-B767_2803-38',
#  'ECLB767-B767_2803-38',
#  'ECLB767-B767_2803-38',
#  'ECLB767-B767_2803-38',
#  'ECLB767-B767_2803-38',
#  'ECLB767-B767_2803-38',
#  'PORB767-B767_2803-39',
#  'PORB767-B767_2803-39',
#  'PORB767-B767_2803-39',
#  'PORB767-B767_2803-39',
#  'PORB767-B767_2803-39',
#  'PORB767-B767_2803-39',
#  'SYSB767-B767_2803-40',
#  'SYSB767-B767_2803-40',
#  'SYSB767-B767_2803-40',
#  'SYSB767-B767_2803-40',
#  'SYSB767-B767_2803-40',
#  'SYSB767-B767_2803-40',
#  'PORB767-B767_2803-41',
#  'PORB767-B767_2803-41',
#  'PORB767-B767_2803-41',
#  'PORB767-B767_2803-41',
#  'PORB767-B767_2803-41',
#  'PORB767-B767_2803-41',
#  'HUBB767-B767_2803-42',
#  'HUBB767-B767_2803-42',
#  'HUBB767-B767_2803-42',
#  'HUBB767-B767_2803-42',
#  'HUBB767-B767_2803-42',
#  'HUBB767-B767_2803-42',
#  'ECLB767-B767_2803-43',
#  'ECLB767-B767_2803-43',
#  'ECLB767-B767_2803-43',
#  'ECLB767-B767_2803-43',
#  'ECLB767-B767_2803-43',
#  'ECLB767-B767_2803-43',
#  'SYSB767-B767_2803-44',
#  'SYSB767-B767_2803-44',
#  'SYSB767-B767_2803-44',
#  'SYSB767-B767_2803-44',
#  'SYSB767-B767_2803-44',
#  'SYSB767-B767_2803-44',
#  'REACRJ700-CRJ700_6943-0',
#  'REACRJ700-CRJ700_6943-0',
#  'REACRJ700-CRJ700_6943-0',
#  'REACRJ700-CRJ700_6943-0',
#  'REACRJ700-CRJ700_6943-0',
#  'REACRJ700-CRJ700_6943-1',
#  'REACRJ700-CRJ700_6943-1',
#  'REACRJ700-CRJ700_6943-1',
#  'REACRJ700-CRJ700_6943-1',
#  'REACRJ700-CRJ700_6943-1',
#  'SYSCRJ700-CRJ700_6943-2',
#  'SYSCRJ700-CRJ700_6943-2',
#  'SYSCRJ700-CRJ700_6943-2',
#  'SYSCRJ700-CRJ700_6943-2',
#  'SYSCRJ700-CRJ700_6943-2',
#  'ORDCRJ700-CRJ700_6943-3',
#  'ORDCRJ700-CRJ700_6943-3',
#  'ORDCRJ700-CRJ700_6943-3',
#  'ORDCRJ700-CRJ700_6943-3',
#  'ORDCRJ700-CRJ700_6943-3',
#  'AUTCRJ700-CRJ700_6943-4',
#  'AUTCRJ700-CRJ700_6943-4',
#  'AUTCRJ700-CRJ700_6943-4',
#  'AUTCRJ700-CRJ700_6943-4',
#  'AUTCRJ700-CRJ700_6943-4',
#  'SYSCRJ700-CRJ700_6943-5',
#  'SYSCRJ700-CRJ700_6943-5',
#  'SYSCRJ700-CRJ700_6943-5',
#  'SYSCRJ700-CRJ700_6943-5',
#  'SYSCRJ700-CRJ700_6943-5',
#  'RADCRJ700-CRJ700_6943-6',
#  'RADCRJ700-CRJ700_6943-6',
#  'RADCRJ700-CRJ700_6943-6',
#  'RADCRJ700-CRJ700_6943-6',
#  'RADCRJ700-CRJ700_6943-6',
#  'SYSCRJ700-CRJ700_6943-7',
#  'SYSCRJ700-CRJ700_6943-7',
#  'SYSCRJ700-CRJ700_6943-7',
#  'SYSCRJ700-CRJ700_6943-7',
#  'SYSCRJ700-CRJ700_6943-7',
#  'SYSCRJ700-CRJ700_6943-8',
#  'SYSCRJ700-CRJ700_6943-8',
#  'SYSCRJ700-CRJ700_6943-8',
#  'SYSCRJ700-CRJ700_6943-8',
#  'SYSCRJ700-CRJ700_6943-8',
#  'SYSCRJ700-CRJ700_6943-9',
#  'SYSCRJ700-CRJ700_6943-9',
#  'SYSCRJ700-CRJ700_6943-9',
#  'SYSCRJ700-CRJ700_6943-9',
#  'SYSCRJ700-CRJ700_6943-9',
#  'SYSCRJ700-CRJ700_6943-10',
#  'SYSCRJ700-CRJ700_6943-10',
#  'SYSCRJ700-CRJ700_6943-10',
#  'SYSCRJ700-CRJ700_6943-10',
#  'SYSCRJ700-CRJ700_6943-10',
#  'UNICRJ700-CRJ700_6943-11',
#  'UNICRJ700-CRJ700_6943-11',
#  'UNICRJ700-CRJ700_6943-11',
#  'UNICRJ700-CRJ700_6943-11',
#  'UNICRJ700-CRJ700_6943-11',
#  'SYSCRJ700-CRJ700_6943-12',
#  'SYSCRJ700-CRJ700_6943-12',
#  'SYSCRJ700-CRJ700_6943-12',
#  'SYSCRJ700-CRJ700_6943-12',
#  'SYSCRJ700-CRJ700_6943-12',
#  'SYSCRJ700-CRJ700_6943-13',
#  'SYSCRJ700-CRJ700_6943-13',
#  'SYSCRJ700-CRJ700_6943-13',
#  'SYSCRJ700-CRJ700_6943-13',
#  'SYSCRJ700-CRJ700_6943-13',
#  'SYSCRJ700-CRJ700_6943-14',
#  'SYSCRJ700-CRJ700_6943-14',
#  'SYSCRJ700-CRJ700_6943-14',
#  'SYSCRJ700-CRJ700_6943-14',
#  'SYSCRJ700-CRJ700_6943-14',
#  'SYSCRJ700-CRJ700_6943-15',
#  'SYSCRJ700-CRJ700_6943-15',
#  'SYSCRJ700-CRJ700_6943-15',
#  'SYSCRJ700-CRJ700_6943-15',
#  'SYSCRJ700-CRJ700_6943-15',
#  'GENCRJ700-CRJ700_6943-16',
#  'GENCRJ700-CRJ700_6943-16',
#  'GENCRJ700-CRJ700_6943-16',
#  'GENCRJ700-CRJ700_6943-16',
#  'GENCRJ700-CRJ700_6943-16',
#  'TRACRJ700-CRJ700_6943-17',
#  'TRACRJ700-CRJ700_6943-17',
#  'TRACRJ700-CRJ700_6943-17',
#  'TRACRJ700-CRJ700_6943-17',
#  'TRACRJ700-CRJ700_6943-17',
#  'TRACRJ700-CRJ700_6943-18',
#  'TRACRJ700-CRJ700_6943-18',
#  'TRACRJ700-CRJ700_6943-18',
#  'TRACRJ700-CRJ700_6943-18',
#  'TRACRJ700-CRJ700_6943-18',
#  'SYSCRJ700-CRJ700_6943-19',
#  'SYSCRJ700-CRJ700_6943-19',
#  'SYSCRJ700-CRJ700_6943-19',
#  'SYSCRJ700-CRJ700_6943-19',
#  'SYSCRJ700-CRJ700_6943-19',
#  'AILCRJ700-CRJ700_6943-20',
#  'AILCRJ700-CRJ700_6943-20',
#  'AILCRJ700-CRJ700_6943-20',
#  'AILCRJ700-CRJ700_6943-20',
#  'AILCRJ700-CRJ700_6943-20',
#  'EMPCRJ700-CRJ700_6943-21',
#  'EMPCRJ700-CRJ700_6943-21',
#  'EMPCRJ700-CRJ700_6943-21',
#  'EMPCRJ700-CRJ700_6943-21',
#  'EMPCRJ700-CRJ700_6943-21',
#  'FLACRJ700-CRJ700_6943-22',
#  'FLACRJ700-CRJ700_6943-22',
#  'FLACRJ700-CRJ700_6943-22',
#  'FLACRJ700-CRJ700_6943-22',
#  'FLACRJ700-CRJ700_6943-22',
#  'SPOCRJ700-CRJ700_6943-23',
#  'SPOCRJ700-CRJ700_6943-23',
#  'SPOCRJ700-CRJ700_6943-23',
#  'SPOCRJ700-CRJ700_6943-23',
#  'SPOCRJ700-CRJ700_6943-23',
#  'FRECRJ700-CRJ700_6943-24',
#  'FRECRJ700-CRJ700_6943-24',
#  'FRECRJ700-CRJ700_6943-24',
#  'FRECRJ700-CRJ700_6943-24',
#  'FRECRJ700-CRJ700_6943-24',
#  'SYSCRJ700-CRJ700_6943-25',
#  'SYSCRJ700-CRJ700_6943-25',
#  'SYSCRJ700-CRJ700_6943-25',
#  'SYSCRJ700-CRJ700_6943-25',
#  'SYSCRJ700-CRJ700_6943-25',
#  'GOUCRJ700-CRJ700_6943-26',
#  'GOUCRJ700-CRJ700_6943-26',
#  'GOUCRJ700-CRJ700_6943-26',
#  'GOUCRJ700-CRJ700_6943-26',
#  'GOUCRJ700-CRJ700_6943-26',
#  'SYSCRJ700-CRJ700_6943-27',
#  'SYSCRJ700-CRJ700_6943-27',
#  'SYSCRJ700-CRJ700_6943-27',
#  'SYSCRJ700-CRJ700_6943-27',
#  'SYSCRJ700-CRJ700_6943-27',
#  'SYSCRJ700-CRJ700_6943-28',
#  'SYSCRJ700-CRJ700_6943-28',
#  'SYSCRJ700-CRJ700_6943-28',
#  'SYSCRJ700-CRJ700_6943-28',
#  'SYSCRJ700-CRJ700_6943-28',
#  'SYSCRJ700-CRJ700_6943-29',
#  'SYSCRJ700-CRJ700_6943-29',
#  'SYSCRJ700-CRJ700_6943-29',
#  'SYSCRJ700-CRJ700_6943-29',
#  'SYSCRJ700-CRJ700_6943-29',
#  'ECLCRJ700-CRJ700_6943-30',
#  'ECLCRJ700-CRJ700_6943-30',
#  'ECLCRJ700-CRJ700_6943-30',
#  'ECLCRJ700-CRJ700_6943-30',
#  'ECLCRJ700-CRJ700_6943-30',
#  'SIECRJ700-CRJ700_6943-31',
#  'SIECRJ700-CRJ700_6943-31',
#  'SIECRJ700-CRJ700_6943-31',
#  'SIECRJ700-CRJ700_6943-31',
#  'SIECRJ700-CRJ700_6943-31',
#  'SIECRJ700-CRJ700_6943-32',
#  'SIECRJ700-CRJ700_6943-32',
#  'SIECRJ700-CRJ700_6943-32',
#  'SIECRJ700-CRJ700_6943-32',
#  'SIECRJ700-CRJ700_6943-32',
#  'SYSCRJ700-CRJ700_6943-33',
#  'SYSCRJ700-CRJ700_6943-33',
#  'SYSCRJ700-CRJ700_6943-33',
#  'SYSCRJ700-CRJ700_6943-33',
#  'SYSCRJ700-CRJ700_6943-33',
#  'SYSCRJ700-CRJ700_6943-34',
#  'SYSCRJ700-CRJ700_6943-34',
#  'SYSCRJ700-CRJ700_6943-34',
#  'SYSCRJ700-CRJ700_6943-34',
#  'SYSCRJ700-CRJ700_6943-34',
#  'TOICRJ700-CRJ700_6943-35',
#  'TOICRJ700-CRJ700_6943-35',
#  'TOICRJ700-CRJ700_6943-35',
#  'TOICRJ700-CRJ700_6943-35',
#  'TOICRJ700-CRJ700_6943-35',
#  'SYSCRJ700-CRJ700_6943-36',
#  'SYSCRJ700-CRJ700_6943-36',
#  'SYSCRJ700-CRJ700_6943-36',
#  'SYSCRJ700-CRJ700_6943-36',
#  'SYSCRJ700-CRJ700_6943-36',
#  'DETCRJ700-CRJ700_6943-37',
#  'DETCRJ700-CRJ700_6943-37',
#  'DETCRJ700-CRJ700_6943-37',
#  'DETCRJ700-CRJ700_6943-37',
#  'DETCRJ700-CRJ700_6943-37',
#  'ECLCRJ700-CRJ700_6943-38',
#  'ECLCRJ700-CRJ700_6943-38',
#  'ECLCRJ700-CRJ700_6943-38',
#  'ECLCRJ700-CRJ700_6943-38',
#  'ECLCRJ700-CRJ700_6943-38',
#  'PORCRJ700-CRJ700_6943-39',
#  'PORCRJ700-CRJ700_6943-39',
#  'PORCRJ700-CRJ700_6943-39',
#  'PORCRJ700-CRJ700_6943-39',
#  'PORCRJ700-CRJ700_6943-39',
#  'SYSCRJ700-CRJ700_6943-40',
#  'SYSCRJ700-CRJ700_6943-40',
#  'SYSCRJ700-CRJ700_6943-40',
#  'SYSCRJ700-CRJ700_6943-40',
#  'SYSCRJ700-CRJ700_6943-40',
#  'PORCRJ700-CRJ700_6943-41',
#  'PORCRJ700-CRJ700_6943-41',
#  'PORCRJ700-CRJ700_6943-41',
#  'PORCRJ700-CRJ700_6943-41',
#  'PORCRJ700-CRJ700_6943-41',
#  'HUBCRJ700-CRJ700_6943-42',
#  'HUBCRJ700-CRJ700_6943-42',
#  'HUBCRJ700-CRJ700_6943-42',
#  'HUBCRJ700-CRJ700_6943-42',
#  'HUBCRJ700-CRJ700_6943-42',
#  'ECLCRJ700-CRJ700_6943-43',
#  'ECLCRJ700-CRJ700_6943-43',
#  'ECLCRJ700-CRJ700_6943-43',
#  'ECLCRJ700-CRJ700_6943-43',
#  'ECLCRJ700-CRJ700_6943-43',
#  'SYSCRJ700-CRJ700_6943-44',
#  'SYSCRJ700-CRJ700_6943-44',
#  'SYSCRJ700-CRJ700_6943-44',
#  'SYSCRJ700-CRJ700_6943-44',
#  'SYSCRJ700-CRJ700_6943-44',
#  'REAA350-A350_1177-0',
#  'REAA350-A350_1177-0',
#  'REAA350-A350_1177-0',
#  'REAA350-A350_1177-0',
#  'REAA350-A350_1177-1',
#  'REAA350-A350_1177-1',
#  'REAA350-A350_1177-1',
#  'REAA350-A350_1177-1',
#  'SYSA350-A350_1177-2',
#  'SYSA350-A350_1177-2',
#  'SYSA350-A350_1177-2',
#  'SYSA350-A350_1177-2',
#  'ORDA350-A350_1177-3',
#  'ORDA350-A350_1177-3',
#  'ORDA350-A350_1177-3',
#  'ORDA350-A350_1177-3',
#  'AUTA350-A350_1177-4',
#  'AUTA350-A350_1177-4',
#  'AUTA350-A350_1177-4',
#  'AUTA350-A350_1177-4',
#  'SYSA350-A350_1177-5',
#  'SYSA350-A350_1177-5',
#  'SYSA350-A350_1177-5',
#  'SYSA350-A350_1177-5',
#  'RADA350-A350_1177-6',
#  'RADA350-A350_1177-6',
#  'RADA350-A350_1177-6',
#  'RADA350-A350_1177-6',
#  'SYSA350-A350_1177-7',
#  'SYSA350-A350_1177-7',
#  'SYSA350-A350_1177-7',
#  'SYSA350-A350_1177-7',
#  'SYSA350-A350_1177-8',
#  'SYSA350-A350_1177-8',
#  'SYSA350-A350_1177-8',
#  'SYSA350-A350_1177-8',
#  'SYSA350-A350_1177-9',
#  'SYSA350-A350_1177-9',
#  'SYSA350-A350_1177-9',
#  'SYSA350-A350_1177-9',
#  'SYSA350-A350_1177-10',
#  'SYSA350-A350_1177-10',
#  'SYSA350-A350_1177-10',
#  'SYSA350-A350_1177-10',
#  'UNIA350-A350_1177-11',
#  'UNIA350-A350_1177-11',
#  'UNIA350-A350_1177-11',
#  'UNIA350-A350_1177-11',
#  'SYSA350-A350_1177-12',
#  'SYSA350-A350_1177-12',
#  'SYSA350-A350_1177-12',
#  'SYSA350-A350_1177-12',
#  'SYSA350-A350_1177-13',
#  'SYSA350-A350_1177-13',
#  'SYSA350-A350_1177-13',
#  'SYSA350-A350_1177-13',
#  'SYSA350-A350_1177-14',
#  'SYSA350-A350_1177-14',
#  'SYSA350-A350_1177-14',
#  'SYSA350-A350_1177-14',
#  'SYSA350-A350_1177-15',
#  'SYSA350-A350_1177-15',
#  'SYSA350-A350_1177-15',
#  'SYSA350-A350_1177-15',
#  'GENA350-A350_1177-16',
#  'GENA350-A350_1177-16',
#  'GENA350-A350_1177-16',
#  'GENA350-A350_1177-16',
#  'TRAA350-A350_1177-17',
#  'TRAA350-A350_1177-17',
#  'TRAA350-A350_1177-17',
#  'TRAA350-A350_1177-17',
#  'TRAA350-A350_1177-18',
#  'TRAA350-A350_1177-18',
#  'TRAA350-A350_1177-18',
#  'TRAA350-A350_1177-18',
#  'SYSA350-A350_1177-19',
#  'SYSA350-A350_1177-19',
#  'SYSA350-A350_1177-19',
#  'SYSA350-A350_1177-19',
#  'AILA350-A350_1177-20',
#  'AILA350-A350_1177-20',
#  'AILA350-A350_1177-20',
#  'AILA350-A350_1177-20',
#  'EMPA350-A350_1177-21',
#  'EMPA350-A350_1177-21',
#  'EMPA350-A350_1177-21',
#  'EMPA350-A350_1177-21',
#  'FLAA350-A350_1177-22',
#  'FLAA350-A350_1177-22',
#  'FLAA350-A350_1177-22',
#  'FLAA350-A350_1177-22',
#  'SPOA350-A350_1177-23',
#  'SPOA350-A350_1177-23',
#  'SPOA350-A350_1177-23',
#  'SPOA350-A350_1177-23',
#  'FREA350-A350_1177-24',
#  'FREA350-A350_1177-24',
#  'FREA350-A350_1177-24',
#  'FREA350-A350_1177-24',
#  'SYSA350-A350_1177-25',
#  'SYSA350-A350_1177-25',
#  'SYSA350-A350_1177-25',
#  'SYSA350-A350_1177-25',
#  'GOUA350-A350_1177-26',
#  'GOUA350-A350_1177-26',
#  'GOUA350-A350_1177-26',
#  'GOUA350-A350_1177-26',
#  'SYSA350-A350_1177-27',
#  'SYSA350-A350_1177-27',
#  'SYSA350-A350_1177-27',
#  'SYSA350-A350_1177-27',
#  'SYSA350-A350_1177-28',
#  'SYSA350-A350_1177-28',
#  'SYSA350-A350_1177-28',
#  'SYSA350-A350_1177-28',
#  'SYSA350-A350_1177-29',
#  'SYSA350-A350_1177-29',
#  'SYSA350-A350_1177-29',
#  'SYSA350-A350_1177-29',
#  'ECLA350-A350_1177-30',
#  'ECLA350-A350_1177-30',
#  'ECLA350-A350_1177-30',
#  'ECLA350-A350_1177-30',
#  'SIEA350-A350_1177-31',
#  'SIEA350-A350_1177-31',
#  'SIEA350-A350_1177-31',
#  'SIEA350-A350_1177-31',
#  'SIEA350-A350_1177-32',
#  'SIEA350-A350_1177-32',
#  'SIEA350-A350_1177-32',
#  'SIEA350-A350_1177-32',
#  'SYSA350-A350_1177-33',
#  'SYSA350-A350_1177-33',
#  'SYSA350-A350_1177-33',
#  'SYSA350-A350_1177-33',
#  'SYSA350-A350_1177-34',
#  'SYSA350-A350_1177-34',
#  'SYSA350-A350_1177-34',
#  'SYSA350-A350_1177-34',
#  'TOIA350-A350_1177-35',
#  'TOIA350-A350_1177-35',
#  'TOIA350-A350_1177-35',
#  'TOIA350-A350_1177-35',
#  'SYSA350-A350_1177-36',
#  'SYSA350-A350_1177-36',
#  'SYSA350-A350_1177-36',
#  'SYSA350-A350_1177-36',
#  'DETA350-A350_1177-37',
#  'DETA350-A350_1177-37',
#  'DETA350-A350_1177-37',
#  'DETA350-A350_1177-37',
#  'ECLA350-A350_1177-38',
#  'ECLA350-A350_1177-38',
#  'ECLA350-A350_1177-38',
#  'ECLA350-A350_1177-38',
#  'PORA350-A350_1177-39',
#  'PORA350-A350_1177-39',
#  'PORA350-A350_1177-39',
#  'PORA350-A350_1177-39',
#  'SYSA350-A350_1177-40',
#  'SYSA350-A350_1177-40',
#  'SYSA350-A350_1177-40',
#  'SYSA350-A350_1177-40',
#  'PORA350-A350_1177-41',
#  'PORA350-A350_1177-41',
#  'PORA350-A350_1177-41',
#  'PORA350-A350_1177-41',
#  'HUBA350-A350_1177-42',
#  'HUBA350-A350_1177-42',
#  'HUBA350-A350_1177-42',
#  'HUBA350-A350_1177-42',
#  'ECLA350-A350_1177-43',
#  'ECLA350-A350_1177-43',
#  'ECLA350-A350_1177-43',
#  'ECLA350-A350_1177-43',
#  'SYSA350-A350_1177-44',
#  'SYSA350-A350_1177-44',
#  'SYSA350-A350_1177-44',
#  'SYSA350-A350_1177-44',
#  'REAB777-B777_4029-0',
#  'REAB777-B777_4029-0',
#  'REAB777-B777_4029-0',
#  'REAB777-B777_4029-0',
#  'REAB777-B777_4029-0',
#  'REAB777-B777_4029-0',
#  'REAB777-B777_4029-0',
#  'REAB777-B777_4029-0',
#  'REAB777-B777_4029-1',
#  'REAB777-B777_4029-1',
#  'REAB777-B777_4029-1',
#  'REAB777-B777_4029-1',
#  'REAB777-B777_4029-1',
#  'REAB777-B777_4029-1',
#  'REAB777-B777_4029-1',
#  'REAB777-B777_4029-1',
#  'SYSB777-B777_4029-2',
#  'SYSB777-B777_4029-2',
#  'SYSB777-B777_4029-2',
#  'SYSB777-B777_4029-2',
#  'SYSB777-B777_4029-2',
#  'SYSB777-B777_4029-2',
#  'SYSB777-B777_4029-2',
#  'SYSB777-B777_4029-2',
#  'ORDB777-B777_4029-3',
#  'ORDB777-B777_4029-3',
#  'ORDB777-B777_4029-3',
#  'ORDB777-B777_4029-3',
#  'ORDB777-B777_4029-3',
#  'ORDB777-B777_4029-3',
#  'ORDB777-B777_4029-3',
#  'ORDB777-B777_4029-3',
#  'AUTB777-B777_4029-4',
#  'AUTB777-B777_4029-4',
#  'AUTB777-B777_4029-4',
#  'AUTB777-B777_4029-4',
#  'AUTB777-B777_4029-4',
#  'AUTB777-B777_4029-4',
#  'AUTB777-B777_4029-4',
#  'AUTB777-B777_4029-4',
#  'SYSB777-B777_4029-5',
#  'SYSB777-B777_4029-5',
#  'SYSB777-B777_4029-5',
#  'SYSB777-B777_4029-5',
#  'SYSB777-B777_4029-5',
#  'SYSB777-B777_4029-5',
#  'SYSB777-B777_4029-5',
#  'SYSB777-B777_4029-5',
#  'RADB777-B777_4029-6',
#  'RADB777-B777_4029-6',
#  'RADB777-B777_4029-6',
#  'RADB777-B777_4029-6',
#  'RADB777-B777_4029-6',
#  'RADB777-B777_4029-6',
#  'RADB777-B777_4029-6',
#  ...]

# %%
usure_composant(data,'AUTE170-E170_6353-4')

# %%
comparaison_usure(data, 'REAE170-E170_6353-0', 'REAE170-E170_6353-1')

# %%
"""


"""
